# %%
# Symbolic Link 
# !ln -s /content/drive/MyDrive/ /mydrive

# %%
# clone "Darknet git repository" to yolov4
# %cd /mydrive/yolov4
# !git clone https://github.com/AlexeyAB/darknet

# %% [markdown]
# 1. Data Annotation Tool LabelImg
# - annotate custom training data for YOLOv4 by using the LabelImg tool
#     1. Provide the images directory along with the output directory(where you want to save the corresponding text files).
#     2. Change the format from PascalVOC to YOLO
#     3. Label each object (by drawing bounding boxes around them) in each image with its respective name (labelImg automatically assigns zero-indexed ids to the classes)

# %%
# !nvidia-smi

# %%
# %cd /content/drive/MyDrive/yolov4/darknet

# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# !sed -i 's/OPENMP=0/OPENMP=1/' Makefile

# %%
# !make

# %% [markdown]
# Configuration File
#
# a) Train.txt File
#
# b) Obj.names File
#
# c) Obj.data File
#
# d) Cfg File

# %%
import glob
x = '.jpg'
imglist = glob.glob("/content/drive/MyDrive/train/*{}".format(x), recursive=False)
print(len(imglist))
with open("/content/drive/MyDrive/train.txt", 'w', encoding='utf-8') as f:
    for img in imglist:
        img = img.replace("\\", "/")
        f.write(img+'\n')

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %% [markdown]
# Starting Training

# %%
# !./darknet detector train /content/drive/MyDrive/train/obj.data /content/drive/MyDrive/train/yolo-obj.cfg /content/drive/MyDrive/yolov4/darknet/yolov4.conv.137 -dont_show -map

# %%
# !./darknet detector map /content/drive/MyDrive/train/obj.data /content/drive/MyDrive/train/yolov4-obj.cfg /content/drive/MyDrive/outputs/yolov4-obj_1000.weights

# %%
# !./darknet detector test /content/drive/MyDrive/train/obj.data /content/drive/MyDrive/train/yolo-obj.cfg <weight file> <query image/video> -thresh <x>
